# %%
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')
print(stopwords.words('english'))
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "D:\ana\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "D:\ana\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "D:\ana\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "D:\ana\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "D:\ana\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "D:\ana\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "D:\ana\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "D:\ana\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "D:\ana\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "D:\ana\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\член\AppData\Local\Temp\ipykernel_27552\3658781451.py", line 1, in <module>
#     import nltk
#   File "D:\ana\Lib\site-packages\nltk\__init__.py", line 133, in <module>
#     from nltk.collocations import *
#   File "D:\ana\Lib\site-packages\nltk\collocations.py", line 36, in <module>
#     from nltk.metrics import (
#   File "D:\ana\Lib\site-packages\nltk\metrics\__init__.py", line 18, in <module>
#     from nltk.metrics.association import (
#   File "D:\ana\Lib\site-packages\nltk\metrics\association.py", line 26, in <module>
#     from scipy.stats import fisher_exact
#   File "D:\ana\Lib\site-packages\scipy\stats\__init__.py", line 606, in <module>
#     from ._stats_py import *
#   File "D:\ana\Lib\site-packages\scipy\stats\_stats_py.py", line 37, in <module>
#     from scipy import sparse
#   File "D:\ana\Lib\site-packages\scipy\__init__.py", line 134, in __getattr__
#     return _importlib.import_module(f'scipy.{name}')
#   File "D:\ana\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "D:\ana\Lib\site-packages\scipy\sparse\__init__.py", line 295, in <module>
#     from ._csr import *
#   File "D:\ana\Lib\site-packages\scipy\sparse\_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File D:\ana\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "D:\ana\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "D:\ana\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "D:\ana\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "D:\ana\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "D:\ana\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "D:\ana\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "D:\ana\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "D:\ana\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "D:\ana\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "D:\ana\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\член\AppData\Local\Temp\ipykernel_27552\3658781451.py", line 1, in <module>
#     import nltk
#   File "D:\ana\Lib\site-packages\nltk\__init__.py", line 133, in <module>
#     from nltk.collocations import *
#   File "D:\ana\Lib\site-packages\nltk\collocations.py", line 36, in <module>
#     from nltk.metrics import (
#   File "D:\ana\Lib\site-packages\nltk\metrics\__init__.py", line 38, in <module>
#     from nltk.metrics.scores import (
#   File "D:\ana\Lib\site-packages\nltk\metrics\scores.py", line 15, in <module>
#     from scipy.stats.stats import betai
#   File "D:\ana\Lib\site-packages\scipy\stats\__init__.py", line 606, in <module>
#     from ._stats_py import *
#   File "D:\ana\Lib\site-packages\scipy\stats\_stats_py.py", line 37, in <module>
#     from scipy import sparse
#   File "D:\ana\Lib\site-packages\scipy\__init__.py", line 134, in __getattr__
#     return _importlib.import_module(f'scipy.{name}')
#   File "D:\ana\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "D:\ana\Lib\site-packages\scipy\sparse\__init__.py", line 295, in <module>
#     from ._csr import *
#   File "D:\ana\Lib\site-packages\scipy\sparse\_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File D:\ana\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "D:\ana\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "D:\ana\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "D:\ana\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "D:\ana\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "D:\ana\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "D:\ana\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "D:\ana\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "D:\ana\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "D:\ana\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "D:\ana\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\член\AppData\Local\Temp\ipykernel_27552\3658781451.py", line 1, in <module>
#     import nltk
#   File "D:\ana\Lib\site-packages\nltk\__init__.py", line 146, in <module>
#     from nltk.chunk import *
#   File "D:\ana\Lib\site-packages\nltk\chunk\__init__.py", line 155, in <module>
#     from nltk.chunk.api import ChunkParserI
#   File "D:\ana\Lib\site-packages\nltk\chunk\api.py", line 13, in <module>
#     from nltk.chunk.util import ChunkScore
#   File "D:\ana\Lib\site-packages\nltk\chunk\util.py", line 12, in <module>
#     from nltk.tag.mapping import map_tag
#   File "D:\ana\Lib\site-packages\nltk\tag\__init__.py", line 70, in <module>
#     from nltk.tag.sequential import (
#   File "D:\ana\Lib\site-packages\nltk\tag\sequential.py", line 26, in <module>
#     from nltk.classify import NaiveBayesClassifier
#   File "D:\ana\Lib\site-packages\nltk\classify\__init__.py", line 97, in <module>
#     from nltk.classify.scikitlearn import SklearnClassifier
#   File "D:\ana\Lib\site-packages\nltk\classify\scikitlearn.py", line 38, in <module>
#     from sklearn.feature_extraction import DictVectorizer
#   File "D:\ana\Lib\site-packages\sklearn\__init__.py", line 87, in <module>
#     from .base import clone
#   File "D:\ana\Lib\site-packages\sklearn\base.py", line 19, in <module>
#     from .utils import _IS_32BIT
#   File "D:\ana\Lib\site-packages\sklearn\utils\__init__.py", line 16, in <module>
#     from scipy.sparse import issparse
#   File "D:\ana\Lib\site-packages\scipy\sparse\__init__.py", line 295, in <module>
#     from ._csr import *
#   File "D:\ana\Lib\site-packages\scipy\sparse\_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File D:\ana\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "D:\ana\Lib\site-packages\ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "D:\ana\Lib\site-packages\traitlets\config\application.py", line 1075, in launch_instance
#     app.start()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelapp.py", line 701, in start
#     self.io_loop.start()
#   File "D:\ana\Lib\site-packages\tornado\platform\asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "D:\ana\Lib\asyncio\windows_events.py", line 322, in run_forever
#     super().run_forever()
#   File "D:\ana\Lib\asyncio\base_events.py", line 641, in run_forever
#     self._run_once()
#   File "D:\ana\Lib\asyncio\base_events.py", line 1987, in _run_once
#     handle._run()
#   File "D:\ana\Lib\asyncio\events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 534, in dispatch_queue
#     await self.process_one()
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 523, in process_one
#     await dispatch(*args)
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 429, in dispatch_shell
#     await result
#   File "D:\ana\Lib\site-packages\ipykernel\kernelbase.py", line 767, in execute_request
#     reply_content = await reply_content
#   File "D:\ana\Lib\site-packages\ipykernel\ipkernel.py", line 429, in do_execute
#     res = shell.run_cell(
#   File "D:\ana\Lib\site-packages\ipykernel\zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "D:\ana\Lib\site-packages\IPython\core\async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "D:\ana\Lib\site-packages\IPython\core\interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "C:\Users\член\AppData\Local\Temp\ipykernel_27552\3658781451.py", line 1, in <module>
#     import nltk
#   File "D:\ana\Lib\site-packages\nltk\__init__.py", line 146, in <module>
#     from nltk.chunk import *
#   File "D:\ana\Lib\site-packages\nltk\chunk\__init__.py", line 155, in <module>
#     from nltk.chunk.api import ChunkParserI
#   File "D:\ana\Lib\site-packages\nltk\chunk\api.py", line 15, in <module>
#     from nltk.parse import ParserI
#   File "D:\ana\Lib\site-packages\nltk\parse\__init__.py", line 100, in <module>
#     from nltk.parse.transitionparser import TransitionParser
#   File "D:\ana\Lib\site-packages\nltk\parse\transitionparser.py", line 17, in <module>
#     from scipy import sparse
#   File "D:\ana\Lib\site-packages\scipy\__init__.py", line 134, in __getattr__
#     return _importlib.import_module(f'scipy.{name}')
#   File "D:\ana\Lib\importlib\__init__.py", line 90, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#   File "D:\ana\Lib\site-packages\scipy\sparse\__init__.py", line 295, in <module>
#     from ._csr import *
#   File "D:\ana\Lib\site-packages\scipy\sparse\_csr.py", line 11, in <module>
#     from ._sparsetools import (csr_tocsc, csr_tobsr, csr_count_blocks,
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# File D:\ana\Lib\site-packages\numpy\core\_multiarray_umath.py:44, in __getattr__(attr_name)
#      39     # Also print the message (with traceback).  This is because old versions
#      40     # of NumPy unfortunately set up the import to replace (and hide) the
#      41     # error.  The traceback shouldn't be needed, but e.g. pytest plugins
#      42     # seem to swallow it and we should be failing anyway...
#      43     sys.stderr.write(msg + tb_msg)
# ---> 44     raise ImportError(msg)
#      46 ret = getattr(_multiarray_umath, attr_name, None)
#      47 if ret is None:
#
# ImportError:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.2.6 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
# ['a', 'about', 'above', 'after', 'again', 'against', 'ain', 'all', 'am', 'an', 'and', 'any', 'are', 'aren', "aren't", 'as', 'at', 'be', 'because', 'been', 'before', 'being', 'below', 'between', 'both', 'but', 'by', 'can', 'couldn', "couldn't", 'd', 'did', 'didn', "didn't", 'do', 'does', 'doesn', "doesn't", 'doing', 'don', "don't", 'down', 'during', 'each', 'few', 'for', 'from', 'further', 'had', 'hadn', "hadn't", 'has', 'hasn', "hasn't", 'have', 'haven', "haven't", 'having', 'he', "he'd", "he'll", 'her', 'here', 'hers', 'herself', "he's", 'him', 'himself', 'his', 'how', 'i', "i'd", 'if', "i'll", "i'm", 'in', 'into', 'is', 'isn', "isn't", 'it', "it'd", "it'll", "it's", 'its', 'itself', "i've", 'just', 'll', 'm', 'ma', 'me', 'mightn', "mightn't", 'more', 'most', 'mustn', "mustn't", 'my', 'myself', 'needn', "needn't", 'no', 'nor', 'not', 'now', 'o', 'of', 'off', 'on', 'once', 'only', 'or', 'other', 'our', 'ours', 'ourselves', 'out', 'over', 'own', 're', 's', 'same', 'shan', "shan't", 'she', "she'd", "she'll", "she's", 'should', 'shouldn', "shouldn't", "should've", 'so', 'some', 'such', 't', 'than', 'that', "that'll", 'the', 'their', 'theirs', 'them', 'themselves', 'then', 'there', 'these', 'they', "they'd", "they'll", "they're", "they've", 'this', 'those', 'through', 'to', 'too', 'under', 'until', 'up', 've', 'very', 'was', 'wasn', "wasn't", 'we', "we'd", "we'll", "we're", 'were', 'weren', "weren't", "we've", 'what', 'when', 'where', 'which', 'while', 'who', 'whom', 'why', 'will', 'with', 'won', "won't", 'wouldn', "wouldn't", 'y', 'you', "you'd", "you'll", 'your', "you're", 'yours', 'yourself', 'yourselves', "you've"]
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\член\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# ### Examples from lab

# %%
import nltk
from nltk.stem import PorterStemmer
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.lancaster import LancasterStemmer

 # Create Snowball stemmer
snow_stemmer = SnowballStemmer(language='english')

# Create a Porter Stemmer instance
porter_stemmer = PorterStemmer()

# Create a Lancaster Stemmer instance
lancaster_stemmer = LancasterStemmer()

# Example words for stemming
words = ["running", "jumps", "happily", "programming", 'cared','fairly','sportingly']

# %%
stemmed_words = [porter_stemmer.stem(word) for word in words]
print("===Porter===:")
print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# ===Porter===:
# Original words: ['running', 'jumps', 'happily', 'programming', 'cared', 'fairly', 'sportingly']
# Stemmed words: ['run', 'jump', 'happili', 'program', 'care', 'fairli', 'sportingli']

# %%
print("\n===Snowball===:")
stemmed_words = [snow_stemmer.stem(word) for word in words]
print("Porter:")
print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# ===Snowball===:
# Porter:
# Original words: ['running', 'jumps', 'happily', 'programming', 'cared', 'fairly', 'sportingly']
# Stemmed words: ['run', 'jump', 'happili', 'program', 'care', 'fair', 'sport']

# %%
print("\n===Lancaster===:")
stemmed_words = [lancaster_stemmer.stem(word) for word in words]
print("Porter:")
print("Original words:", words)
print("Stemmed words:", stemmed_words)
# Out:
# ===Lancaster===:
# Porter:
# Original words: ['running', 'jumps', 'happily', 'programming', 'cared', 'fairly', 'sportingly']
# Stemmed words: ['run', 'jump', 'happy', 'program', 'car', 'fair', 'sport']

# %%
# !pip install "numpy>2" --force-reinstall
# Out:
# Collecting numpy>2
#   Downloading numpy-2.3.0-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.9 kB 330.3 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 649.3 kB/s eta 0:00:00
# Downloading numpy-2.3.0-cp312-cp312-win_amd64.whl (12.7 MB)
#    ---------------------------------------- 0.0/12.7 MB ? eta -:--:--
#    ---------------------------------------- 0.1/12.7 MB 3.3 MB/s eta 0:00:04
#    - -------------------------------------- 0.4/12.7 MB 5.5 MB/s eta 0:00:03
#    --- ------------------------------------ 1.0/12.7 MB 7.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.5/12.7 MB 8.6 MB/s eta 0:00:02
#    ------ --------------------------------- 2.0/12.7 MB 9.3 MB/s eta 0:00:02
#    -------- ------------------------------- 2.6/12.7 MB 9.6 MB/s eta 0:00:02
#    --------- ------------------------------ 3.0/12.7 MB 9.7 MB/s eta 0:00:02
#    ----------- ---------------------------- 3.6/12.7 MB 10.0 MB/s eta 0:00:01
#    ------------ --------------------------- 4.1/12.7 MB 10.0 MB/s eta 0:00:01
#    -------------- ------------------------- 4.6/12.7 MB 10.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 5.1/12.7 MB 10.2 MB/s eta 0:00:01
#    ----------------- ---------------------- 5.6/12.7 MB 10.3 MB/s eta 0:00:01
#    ------------------- -------------------- 6.1/12.7 MB 10.3 MB/s eta 0:00:01
#    -------------------- ------------------- 6.7/12.7 MB 10.4 MB/s eta 0:00:01
#    ---------------------- ----------------- 7.1/12.7 MB 10.4 MB/s eta 0:00:01
#    ------------------------ --------------- 7.7/12.7 MB 10.5 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------- -------------- 8.0/12.7 MB 10.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 9.1/12.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------------ --------- 9.6/12.7 MB 10.6 MB/s eta 0:00:01
#    ------------------------------- -------- 10.2/12.7 MB 10.6 MB/s eta 0:00:01
#    --------------------------------- ------ 10.7/12.7 MB 10.9 MB/s eta 0:00:01
#    ----------------------------------- ---- 11.2/12.7 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------ --- 11.6/12.7 MB 10.9 MB/s eta 0:00:01
#    ------------------------------------ --- 11.6/12.7 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------- -- 12.0/12.7 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------- 12.7/12.7 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: numpy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# Successfully installed numpy-2.3.0
# WARNING: Ignoring invalid distribution ~atplotlib (D:\ana\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (D:\ana\Lib\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# seaborn 0.13.2 requires matplotlib!=3.6.1,>=3.4, which is not installed.
# contourpy 1.2.0 requires numpy<2.0,>=1.20, but you have numpy 2.3.0 which is incompatible.
# cupy 13.4.1 requires numpy<2.3,>=1.22, but you have numpy 2.3.0 which is incompatible.
# numba 0.59.1 requires numpy<1.27,>=1.22, but you have numpy 2.3.0 which is incompatible.
# pywavelets 1.5.0 requires numpy<2.0,>=1.22.4, but you have numpy 2.3.0 which is incompatible.
# scattertext 0.2.2 requires scipy<1.14.0,>=1.7.0, but you have scipy 1.15.3 which is incompatible.
# streamlit 1.32.0 requires numpy<2,>=1.19.3, but you have numpy 2.3.0 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.0 which is incompatible.

# %%
# !pip install --upgrade matplotlib scipy pandas
# Out:
# Requirement already satisfied: matplotlib in d:\ana\lib\site-packages (3.8.4)
# Collecting matplotlib
#   Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl.metadata (11 kB)
# Requirement already satisfied: scipy in d:\ana\lib\site-packages (1.13.1)
# Collecting scipy
#   Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.8 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 814.9 kB/s eta 0:00:00
# Requirement already satisfied: pandas in d:\ana\lib\site-packages (2.2.2)
# Collecting pandas
#   Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: contourpy>=1.0.1 in d:\ana\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in d:\ana\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in d:\ana\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in d:\ana\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.23 in d:\ana\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in d:\ana\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in d:\ana\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in d:\ana\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in d:\ana\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in d:\ana\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in d:\ana\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in d:\ana\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Downloading matplotlib-3.10.3-cp312-cp312-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.2/8.1 MB 4.8 MB/s eta 0:00:02
#    --- ------------------------------------ 0.8/8.1 MB 8.4 MB/s eta 0:00:01
#    ------ --------------------------------- 1.3/8.1 MB 9.3 MB/s eta 0:00:01
#    --------- ------------------------------ 1.8/8.1 MB 9.7 MB/s eta 0:00:01
#    ----------- ---------------------------- 2.4/8.1 MB 10.2 MB/s eta 0:00:01
#    -------------- ------------------------- 2.9/8.1 MB 10.3 MB/s eta 0:00:01
#    ----------------- ---------------------- 3.4/8.1 MB 10.4 MB/s eta 0:00:01
#    ------------------- -------------------- 3.9/8.1 MB 10.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 4.5/8.1 MB 10.6 MB/s eta 0:00:01
#    ------------------------ --------------- 5.0/8.1 MB 10.7 MB/s eta 0:00:01
#    --------------------------- ------------ 5.6/8.1 MB 10.8 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.7/8.1 MB 10.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 5.7/8.1 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 7.0/8.1 MB 10.6 MB/s eta 0:00:01
#    ------------------------------------- -- 7.5/8.1 MB 10.6 MB/s eta 0:00:01
#    ---------------------------------------  8.0/8.1 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 10.5 MB/s eta 0:00:00
# Downloading scipy-1.15.3-cp312-cp312-win_amd64.whl (41.0 MB)
#    ---------------------------------------- 0.0/41.0 MB ? eta -:--:--
#     --------------------------------------- 0.6/41.0 MB 11.8 MB/s eta 0:00:04
#    - -------------------------------------- 1.0/41.0 MB 11.0 MB/s eta 0:00:04
#    - -------------------------------------- 1.6/41.0 MB 11.2 MB/s eta 0:00:04
#    -- ------------------------------------- 2.1/41.0 MB 11.1 MB/s eta 0:00:04
#    -- ------------------------------------- 2.6/41.0 MB 11.1 MB/s eta 0:00:04
#    --- ------------------------------------ 3.1/41.0 MB 11.0 MB/s eta 0:00:04
#    --- ------------------------------------ 3.6/41.0 MB 11.0 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.1/41.0 MB 10.9 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.6/41.0 MB 10.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.1/41.0 MB 10.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.6/41.0 MB 10.9 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.1/41.0 MB 10.9 MB/s eta 0:00:04
#    ------ --------------------------------- 6.7/41.0 MB 10.9 MB/s eta 0:00:04
#    ------- -------------------------------- 7.2/41.0 MB 11.0 MB/s eta 0:00:04
#    ------- -------------------------------- 7.7/41.0 MB 11.0 MB/s eta 0:00:04
#    -------- ------------------------------- 8.3/41.0 MB 11.0 MB/s eta 0:00:03
#    -------- ------------------------------- 8.8/41.0 MB 11.0 MB/s eta 0:00:03
#    --------- ------------------------------ 9.3/41.0 MB 11.0 MB/s eta 0:00:03
#    --------- ------------------------------ 9.6/41.0 MB 11.0 MB/s eta 0:00:03
#    --------- ------------------------------ 9.6/41.0 MB 11.0 MB/s eta 0:00:03
#    ---------- ----------------------------- 10.6/41.0 MB 10.7 MB/s eta 0:00:03
#    ---------- ----------------------------- 11.1/41.0 MB 10.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 11.5/41.0 MB 10.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.1/41.0 MB 10.7 MB/s eta 0:00:03
#    ------------ --------------------------- 12.6/41.0 MB 10.7 MB/s eta 0:00:03
#    ------------ --------------------------- 13.1/41.0 MB 10.7 MB/s eta 0:00:03
#    ------------- -------------------------- 13.7/41.0 MB 10.7 MB/s eta 0:00:03
#    ------------- -------------------------- 14.2/41.0 MB 10.7 MB/s eta 0:00:03
#    -------------- ------------------------- 14.8/41.0 MB 10.9 MB/s eta 0:00:03
#    -------------- ------------------------- 15.3/41.0 MB 10.7 MB/s eta 0:00:03
#    --------------- ------------------------ 15.8/41.0 MB 10.9 MB/s eta 0:00:03
#    --------------- ------------------------ 16.3/41.0 MB 11.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 16.8/41.0 MB 10.9 MB/s eta 0:00:03
#    ---------------- ----------------------- 17.3/41.0 MB 10.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 17.8/41.0 MB 10.9 MB/s eta 0:00:03
#    ----------------- ---------------------- 18.3/41.0 MB 10.9 MB/s eta 0:00:03
#    ------------------ --------------------- 18.8/41.0 MB 10.7 MB/s eta 0:00:03
#    ------------------ --------------------- 19.3/41.0 MB 10.7 MB/s eta 0:00:03
#    ------------------- -------------------- 19.8/41.0 MB 10.7 MB/s eta 0:00:02
#    ------------------- -------------------- 20.3/41.0 MB 11.5 MB/s eta 0:00:02
#    -------------------- ------------------- 20.9/41.0 MB 11.1 MB/s eta 0:00:02
#    -------------------- ------------------- 21.4/41.0 MB 11.1 MB/s eta 0:00:02
#    --------------------- ------------------ 21.9/41.0 MB 11.1 MB/s eta 0:00:02
#    --------------------- ------------------ 22.4/41.0 MB 11.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 22.9/41.0 MB 11.1 MB/s eta 0:00:02
#    ---------------------- ----------------- 23.5/41.0 MB 11.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 23.9/41.0 MB 11.1 MB/s eta 0:00:02
#    ----------------------- ---------------- 24.4/41.0 MB 11.1 MB/s eta 0:00:02
#    ------------------------ --------------- 25.0/41.0 MB 11.1 MB/s eta 0:00:02
#    ------------------------ --------------- 25.5/41.0 MB 11.1 MB/s eta 0:00:02
#    ------------------------- -------------- 26.0/41.0 MB 10.9 MB/s eta 0:00:02
#    ------------------------- -------------- 26.5/41.0 MB 10.9 MB/s eta 0:00:02
#    -------------------------- ------------- 27.0/41.0 MB 10.9 MB/s eta 0:00:02
#    -------------------------- ------------- 27.5/41.0 MB 10.9 MB/s eta 0:00:02
#    --------------------------- ------------ 28.0/41.0 MB 10.9 MB/s eta 0:00:02
#    --------------------------- ------------ 28.6/41.0 MB 10.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 29.1/41.0 MB 11.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 29.6/41.0 MB 11.1 MB/s eta 0:00:02
#    ----------------------------- ---------- 30.2/41.0 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 30.7/41.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------ --------- 31.2/41.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------ --------- 31.6/41.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 32.0/41.0 MB 10.9 MB/s eta 0:00:01
#    ------------------------------- -------- 32.3/41.0 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 32.9/41.0 MB 10.6 MB/s eta 0:00:01
#    -------------------------------- ------- 33.4/41.0 MB 10.7 MB/s eta 0:00:01
#    --------------------------------- ------ 34.0/41.0 MB 10.7 MB/s eta 0:00:01
#    --------------------------------- ------ 34.5/41.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.0/41.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 35.6/41.0 MB 10.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.1/41.0 MB 10.7 MB/s eta 0:00:01
#    ----------------------------------- ---- 36.6/41.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 37.1/41.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------ --- 37.6/41.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------- -- 38.1/41.0 MB 10.7 MB/s eta 0:00:01
#    ------------------------------------- -- 38.7/41.0 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 39.2/41.0 MB 10.7 MB/s eta 0:00:01
#    -------------------------------------- - 39.7/41.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  40.3/41.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  40.8/41.0 MB 10.7 MB/s eta 0:00:01
#    ---------------------------------------  41.0/41.0 MB 10.9 MB/s eta 0:00:01
#    ---------------------------------------- 41.0/41.0 MB 10.2 MB/s eta 0:00:00
# Downloading pandas-2.3.0-cp312-cp312-win_amd64.whl (11.0 MB)
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    - -------------------------------------- 0.5/11.0 MB 10.9 MB/s eta 0:00:01
#    --- ------------------------------------ 1.1/11.0 MB 13.4 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.6/11.0 MB 12.5 MB/s eta 0:00:01
#    ------- -------------------------------- 2.0/11.0 MB 11.7 MB/s eta 0:00:01
#    --------- ------------------------------ 2.5/11.0 MB 11.3 MB/s eta 0:00:01
#    ---------- ----------------------------- 3.0/11.0 MB 11.1 MB/s eta 0:00:01
#    ------------ --------------------------- 3.5/11.0 MB 11.2 MB/s eta 0:00:01
#    -------------- ------------------------- 4.0/11.0 MB 11.1 MB/s eta 0:00:01
#    ---------------- ----------------------- 4.6/11.0 MB 11.2 MB/s eta 0:00:01
#    ------------------ --------------------- 5.1/11.0 MB 11.2 MB/s eta 0:00:01
#    -------------------- ------------------- 5.6/11.0 MB 11.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.0/11.0 MB 11.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.6/11.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 11.1 MB/s eta 0:00:01
#    --------------------------- ------------ 7.6/11.0 MB 11.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.1/11.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 11.1 MB/s eta 0:00:01
#    --------------------------------- ------ 9.2/11.0 MB 11.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 9.8/11.0 MB 11.1 MB/s eta 0:00:01
#    ------------------------------------- -- 10.3/11.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  10.8/11.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------  11.0/11.0 MB 11.1 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 10.6 MB/s eta 0:00:00
# Installing collected packages: scipy, pandas, matplotlib
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.13.1
#     Uninstalling scipy-1.13.1:
#       Successfully uninstalled scipy-1.13.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.8.4
#     Uninstalling matplotlib-3.8.4:
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'd:\\ana\\lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'
# Consider using the `--user` option or check the permissions.

# %% [markdown]
# ### Task 0:
# Compare frequency distributions of stemmed and unstemmed NLTK corpora. Display most commonly used stems from nltk.text corpora on a plot.

# %%
import nltk
from nltk.book import text1 
from nltk.stem import PorterStemmer
import matplotlib.pyplot as plt

nltk.download('book')

porter = PorterStemmer()

words = [word.lower() for word in text1 if word.isalpha()]
stemmed_words = [porter.stem(word) for word in words]

fdist_original = nltk.FreqDist(words)
fdist_stemmed = nltk.FreqDist(stemmed_words)

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
fdist_original.plot(20, title="Top 20 Original Words")

plt.subplot(1, 2, 2)
fdist_stemmed.plot(20, title="Top 20 Stemmed Words")

plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[30], line 4
#       2 from nltk.book import text1
#       3 from nltk.stem import PorterStemmer
# ----> 4 import matplotlib.pyplot as plt
#       6 nltk.download('book')
#       8 porter = PorterStemmer()
#
# File D:\ana\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
#     160 # definitions, so it is safe to import from it here.
# --> 161 from . import _api, _version, cbook, _docstring, rcsetup
#     162 from matplotlib.cbook import sanitize_sequence
#     163 from matplotlib._api import MatplotlibDeprecationWarning
#
# File D:\ana\Lib\site-packages\matplotlib\rcsetup.py:27
#      25 from matplotlib import _api, cbook
#      26 from matplotlib.cbook import ls_mapper
# ---> 27 from matplotlib.colors import Colormap, is_color_like
#      28 from matplotlib._fontconfig_pattern import parse_fontconfig_pattern
#      29 from matplotlib._enums import JoinStyle, CapStyle
#
# ModuleNotFoundError: No module named 'matplotlib.colors'

# %% [markdown]
# ### Task 1:
# Write your own version of stemmer for Ukrainian (or other non-English language) using regular expressions.

# %%
import re
from nltk.stem.api import StemmerI

# %%
class SpanishRegexpStemmer(StemmerI):
    def __init__(self):
        # Основні суфікси іспанської мови, які можна видалити для отримання основи слова
        self.suffixes = [
            r'amiento$', r'imiento$', r'ación$', r'iciones$', r'adora$', r'ador$', r'ante$', r'ancia$', r'anzo$', r'encia$',
            r'ico$', r'ica$', r'ismo$', r'ista$', r'ivo$', r'iva$', r'oso$', r'osa$', r'eza$', r'ado$', r'ada$',
            r'ido$', r'ida$', r'ar$', r'er$', r'ir$', r'ando$', r'iendo$', r'iendo$', r'aba$', r'abas$', r'ábamos$',
            r'aban$', r'ía$', r'ías$', r'íamos$', r'ían$', r'aste$', r'ó$', r'amos$', r'aron$', r'í$', r'iste$',
            r'ió$', r'imos$', r'ieron$', r'aba$', r'abas$', r'aba$', r'ábamos$', r'aban$', r'ase$', r'ases$',
            r'ase$', r'ásemos$', r'asen$', r'iese$', r'ieses$', r'iese$', r'iésemos$', r'iesen$', r'aría$', r'arías$',
            r'aría$', r'aríamos$', r'arían$', r'aremos$', r'aréis$', r'arán$', r'aría$', r'arías$', r'aría$',
            r'aríamos$', r'arían$', r'ido$', r'ida$', r'idos$', r'idas$', r'iendo$', r'ante$', r'ador$', r'able$',
            r'ible$', r'ista$', r'oso$', r'osa$', r'ador$', r'adora$', r'ista$', r'ante$', r'ancia$', r'encia$',
            r'ico$', r'ica$', r'ismo$', r'ista$', r'ivo$', r'iva$', r'oso$', r'osa$', r'eza$'
        ]
        self.regex = re.compile('|'.join(self.suffixes))
    
    def stem(self, word):
        return self.regex.sub('', word)

# %%
stemmer = SpanishRegexpStemmer()
test_words = ['trabajando', 'comiendo', 'felicidad', 'amoroso', 'vivir', 'cantando', 'bailadora']
stemmed_words = [stemmer.stem(word) for word in test_words]
print(stemmed_words)

# %% [markdown]
# ### Task 2:
# Implement Wagner-Fischer (or Vintsyuk) algorithm for string distance.
#
# Modify the algorithm so that substitution operation cost depends on the key proximity on QWERTY keyboard.
#
# Or consider this table directly:
#
# Implement another modification to the algorithm: include transposition operation, so that you compute a Damerau-Levenshtein distance.

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import math

# %%
qwerty = {
    'q': (0, 0), 'w': (0, 1), 'e': (0, 2), 'r': (0, 3), 't': (0, 4), 'y': (0, 5), 'u': (0, 6), 'i': (0, 7), 'o': (0, 8), 'p': (0, 9),
    'a': (1, 0.5), 's': (1, 1.5), 'd': (1, 2.5), 'f': (1, 3.5), 'g': (1, 4.5), 'h': (1, 5.5), 'j': (1, 6.5), 'k': (1, 7.5), 'l': (1, 8.5),
    'z': (2, 1), 'x': (2, 2), 'c': (2, 3), 'v': (2, 4), 'b': (2, 5), 'n': (2, 6), 'm': (2, 7)
}

def qwerty_distance(a, b):
    if a not in qwerty or b not in qwerty:
        return 2
    ax, ay = qwerty[a]
    bx, by = qwerty[b]
    return math.sqrt((ax - bx) ** 2 + (ay - by) ** 2)

def substitution_cost(a, b):
    if a not in qwerty or b not in qwerty:
        return 2.0
    return 0 if a == b else 2.0

def qwerty_cost(a, b):
    return 0 if a == b else qwerty_distance(a, b)

# %% [markdown]
# ### Wagner-Fischer

# %%
def wagner_fischer(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = substitution_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
    return dp[m][n]

# %% [markdown]
# ### Wagner-Fischer(qwerty)

# %%
def wagner_fischer_qwerty(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0.0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = qwerty_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
    return dp[m][n]

# %% [markdown]
# ### Damerau Levenshtein

# %%
def damerau_levenshtein(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = substitution_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
            if i > 1 and j > 1 and s1[i-1] == s2[j-2] and s1[i-2] == s2[j-1]:
                dp[i][j] = min(dp[i][j], dp[i-2][j-2] + 1)
    return dp[m][n]

# %% [markdown]
# ### Damerau Levenshtein(qwerty)

# %%
def damerau_levenshtein_qwerty(s1, s2):
    m, n = len(s1), len(s2)
    dp = [[0.0] * (n+1) for _ in range(m+1)]
    for i in range(m+1): dp[i][0] = i
    for j in range(n+1): dp[0][j] = j

    for i in range(1, m+1):
        for j in range(1, n+1):
            cost = qwerty_cost(s1[i-1], s2[j-1])
            dp[i][j] = min(
                dp[i-1][j] + 1,
                dp[i][j-1] + 1,
                dp[i-1][j-1] + cost
            )
            if i > 1 and j > 1 and s1[i-1] == s2[j-2] and s1[i-2] == s2[j-1]:
                dp[i][j] = min(dp[i][j], dp[i-2][j-2] + 1)
    return dp[m][n]

# %% [markdown]
# ### Graphics

# %%
test_words_pairs = [
    ("cat", "cut"), ("cat", "bat"), ("cat", "dog"), ("cat", "qaz"),
    ("cat", "zzz"), ("kitten", "sitting"), ("play", "plaz"),
    ("keyboard", "keyboqrd"), ("example", "exampqe"),
    ("correct", "korrect"), ("hello", "yello"),
    ("function", "punctuon"), ("semantic", "srmzntid"),
    ("alphabet", "qlphqbst"), ("structure", "xzrudtyre")
]

# %%
words_list = []
for s1, s2 in test_words_pairs:
    words_list.append({
        "Word 1": s1,
        "Word 2": s2,
        "Standard WF": wagner_fischer(s1, s2),
        "QWERTY WF": wagner_fischer_qwerty(s1, s2),
        "Standard DL": damerau_levenshtein(s1, s2),
        "QWERTY DL": damerau_levenshtein_qwerty(s1, s2),
    })

df = pd.DataFrame(words_list)
df_melted = df.melt(id_vars=["Word 1", "Word 2"], var_name="Method", value_name="Distance")
df_melted["Pair"] = df_melted["Word 1"] + " → " + df_melted["Word 2"]

# %%
df.sort_values(by="Standard WF", ascending=False)

# %%
import matplotlib.pyplot as plt
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

fig, axes = plt.subplots(2, 2, figsize=(18, 10))
fig.suptitle("Edit Distance Variants", fontsize=18)

methods = ["Standard WF", "QWERTY WF", "Standard DL", "QWERTY DL"]
axes = axes.flatten()

for ax, method in zip(axes, methods):
    subset = df_melted[df_melted["Method"] == method]
    sns.barplot(data=subset, x="Pair", y="Distance", palette="coolwarm", ax=ax)

    ax.set_title(method)
    ax.set_ylim(0, 9)
    ax.tick_params(axis='x', rotation=45)
    ax.grid(True, linestyle="-", alpha=0.5)
    ax.set_axisbelow(True)
    ax.set_ylabel("Distance")

fig.tight_layout(rect=[0, 0, 1, 1])  
plt.show()
